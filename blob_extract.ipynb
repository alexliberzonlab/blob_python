# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Oct 13 12:36:18 2016

@author: User
"""

from Blob_Reader import extractor
import os
import matplotlib.pyplot as plt
from skimage.io import imread , imshow

# %%
directory = 'data'

blobfiles = ['blob0_2022.07.18_16.26.22_part0.dat',
             'blob1_2022.07.18_16.26.44_part0.dat',
             'blob2_2022.07.18_16.26.59_part0.dat',
             'blob3_2022.07.18_16.27.15_part0.dat']


# directory = 'raw'
# blobfiles = ['b0_part0.dat','b1_part0.dat','b2_part0.dat','b3_part0.dat']

FrameStart = None    # Leave None to go over all the frames
FrameEnd = None    # Leave None to go over all the frames

# parameters for the fitness coefficient:
#window = 5  
#N = 1
#fit_range = [0.5,1.5]

ex = extractor(directory , blobfiles)
ex.load(FrameStart ,FrameEnd)
#ex.search_frames(window,  N, fit_range)
# Out:
# /home/user/Documents/repos/blob_python/data
# unpacking blob0...
# total Frame number: 49901
# unpacking blob1...
# total Frame number: 49901
# unpacking blob2...
# total Frame number: 49901
# unpacking blob3...
# total Frame number: 49901

# %%
fig, ax = ex.plot_frame_count()
fig, ax = ex.plot_frames(FrameStart,FrameEnd)
ex.gen_Target_Files(1, 10)
# plt.hold(True)
# imshow(imread('cam0.tif'))
# Out:
# Warning, overwritting directory
# finished saving targets! start and end frames are:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 fig, ax = ex.plot_frame_count()
#       2 fig, ax = ex.plot_frames(FrameStart,FrameEnd)
# ----> 3 ex.gen_Target_Files(1, 10)
#       4 # plt.hold(True)
#       5 # imshow(imread('cam0.tif'))
#
# File ~/Documents/repos/blob_python/Blob_Reader.py:643, in extractor.gen_Target_Files(self, f_start, f_last, decimals, start_count, entire_range)
#     641 m1,m2 = [],[]
#     642 for i in b:
# --> 643     m1.append(min(i))
#     644     m2.append(max(i))
#     646 print(max( m1 ) , min( m2 ))
#
# ValueError: min() arg is an empty sequence
